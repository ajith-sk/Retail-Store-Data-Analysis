# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/retail_store_sales.csv")

# %%
df_backup = df.copy()

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df.shape
# Out:
# (12575, 11)

# %%
df_backup.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df_backup = df.copy()

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (12575, 11)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df['Item'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12570    False
# 12571    False
# 12572    False
# 12573    False
# 12574    False
# Name: Item, Length: 12575, dtype: bool

# %%
round(df.isnull().sum() * 100 / len(df),2)
# Out:
# Transaction ID       0.00
# Customer ID          0.00
# Category             0.00
# Item                 9.65
# Price Per Unit       4.84
# Quantity             4.80
# Total Spent          4.80
# Payment Method       0.00
# Location             0.00
# Transaction Date     0.00
# Discount Applied    33.39
# dtype: float64

# %%
# 1st working on Items col:

df['Item'] = df['Item'].str.strip()

# %%
df['Item'].replace("",pd.NA,inplace=True)
# Out:
# /tmp/ipython-input-2452819599.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Item'].replace("",pd.NA,inplace=True)

# %%
df.dropna(subset = ['Item'] , inplace=True)

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                   0
# Price Per Unit         0
# Quantity               0
# Total Spent            0
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    3783
# dtype: int64

# %%
df.shape
# Out:
# (11362, 11)

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
df['Discount Applied'].fillna(0)
# Out:
# 0         True
# 1         True
# 2        False
# 3            0
# 4        False
#          ...
# 12570        0
# 12571    False
# 12572        0
# 12573     True
# 12574        0
# Name: Discount Applied, Length: 11362, dtype: object

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                   0
# Price Per Unit         0
# Quantity               0
# Total Spent            0
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    3783
# dtype: int64

# %%
df['Discount Applied'] = df['Discount Applied'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Customer ID         0
# Category            0
# Item                0
# Price Per Unit      0
# Quantity            0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# Discount Applied    0
# dtype: int64

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3                0
# ...

# %%
df.replace(0,"N/A",inplace=True)

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2              N/A
# 3              N/A
# ...

# %%
df['Discount Applied'].reset_index()
# Out:
#        index Discount Applied
# 0          0             True
# 1          1             True
# 2          2              N/A
# 3          3              N/A
# 4          4              N/A
# ...      ...              ...
# 11357  12570              N/A
# 11358  12571              N/A
# 11359  12572              N/A
# 11360  12573             True
# 11361  12574              N/A
#
# [11362 rows x 2 columns]

# %%
df.replace("N/A",False,inplace=True)
# Out:
# /tmp/ipython-input-38176945.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("N/A",False,inplace=True)

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#    Discount Applied
# 0              True
# 1              True
# 2             False
# 3             False
# ...

# %%
df['Discount Applied'].value_counts()
# Out:
# Discount Applied
# False    7561
# True     3801
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
df.loc[df['Payment Method'] == "Credit Card"].head()
# Out:
#    Transaction ID Customer ID   Category         Item  Price Per Unit  \
# 2     TXN_9303719     CUST_02   Butchers  Item_12_BUT            21.5
# 3     TXN_9458126     CUST_06  Beverages  Item_16_BEV            27.5
# 6     TXN_3652209     CUST_07       Food  Item_1_FOOD             5.0
# 8     TXN_9728486     CUST_23  Furniture  Item_16_FUR            27.5
# 26    TXN_9057609     CUST_18   Butchers  Item_20_BUT            33.5
#
#     Quantity  Total Spent Payment Method  Location Transaction Date  \
# 2        2.0         43.0    Credit Card    Online       2022-10-05
# 3        9.0        247.5    Credit Card    Online       2022-05-07
# 6        8.0         40.0    Credit Card  In-store       2023-06-10
# 8        1.0         27.5    Credit Card  In-store       2023-04-26
# 26       4.0        134.0    Credit Card  In-store       2022-03-16
#
#     Discount Applied
# 2              False
# 3              False
# 6               True
# 8              False
# 26              True

# %%
df['Total_Calculation'] = df['Quantity'] * df['Price Per Unit']

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#    Discount Applied  Total_Calculation
# 0              True              185.0
# ...

# %%
df['Total Spent'].nunique()
# Out:
# 227

# %%
df['Total_Calculation'].nunique()
# Out:
# 227

# %%
df['Payment Method'].unique()
# Out:
# array(['Digital Wallet', 'Credit Card', 'Cash'], dtype=object)

# %%
df.drop('Total_Calculation',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#    Discount Applied
# 0              True
# 1              True
# 2             False
# 3             False
# ...

# %%
df.keys()   # returns axis labels.
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
df.columns  # returns returns column names.
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
df.groupby('Category')['Quantity'].sum()
# Out:
# Category
# Beverages                             7974.0
# Butchers                              7774.0
# Computers and electric accessories    7832.0
# Electric household essentials         7897.0
# Food                                  7925.0
# Furniture                             8083.0
# Milk Products                         7889.0
# Patisserie                            7515.0
# Name: Quantity, dtype: float64

# %%
df.groupby('Category')['Quantity'].sum().plot(kind='bar',color='#dde80c',hatch='//')
plt.xticks(rotation = 80 , fontsize= 9)
plt.xlabel('Category')
plt.ylabel('Quantity Sold')
plt.title('Quantity Sold by Category')
#plt.tight_layout()  # decrases the height
plt.show()

# %%
df.groupby('Category')['Total Spent'].sum()
# Out:
# Category
# Beverages                             187978.5
# Butchers                              197426.0
# Computers and electric accessories    180902.5
# Electric household essentials         192441.5
# Food                                  184645.0
# Furniture                             186527.0
# Milk Products                         170747.5
# Patisserie                            172330.5
# Name: Total Spent, dtype: float64

# %%
df.groupby('Category')['Total Spent'].mean()
# Out:
# Category
# Beverages                             131.729853
# Butchers                              138.934553
# Computers and electric accessories    129.493558
# Electric household essentials         133.918928
# Food                                  129.484572
# Furniture                             127.758219
# Milk Products                         119.822807
# Patisserie                            125.880570
# Name: Total Spent, dtype: float64

# %%
df.groupby('Category')['Total Spent'].sum().sort_values(ascending = False)
# Out:
# Category
# Butchers                              197426.0
# Electric household essentials         192441.5
# Beverages                             187978.5
# Furniture                             186527.0
# Food                                  184645.0
# Computers and electric accessories    180902.5
# Patisserie                            172330.5
# Milk Products                         170747.5
# Name: Total Spent, dtype: float64

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Customer ID         0
# Category            0
# Item                0
# Price Per Unit      0
# Quantity            0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# Discount Applied    0
# dtype: int64

# %%
df.dtypes
# Out:
# Transaction ID       object
# Customer ID          object
# Category             object
# Item                 object
# Price Per Unit      float64
# Quantity            float64
# Total Spent         float64
# Payment Method       object
# Location             object
# Transaction Date     object
# Discount Applied       bool
# dtype: object

# %%
df['Quantity'] = df['Quantity'].astype(int)

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# %%
df.dtypes
# Out:
# Transaction ID              object
# Customer ID                 object
# Category                    object
# Item                        object
# Price Per Unit             float64
# Quantity                     int64
# Total Spent                float64
# Payment Method              object
# Location                    object
# Transaction Date    datetime64[ns]
# Discount Applied              bool
# dtype: object

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.replace(" ","_")

# %%
df.head()
# Out:
#   Transaction_ID Customer_ID       Category          Item  Price_Per_Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total_Spent  Payment_Method Location Transaction_Date  \
# 0        10        185.0  Digital Wallet   Online       2024-04-08
# 1         9        261.0  Digital Wallet   Online       2023-07-23
# 2         2         43.0     Credit Card   Online       2022-10-05
# 3         9        247.5     Credit Card   Online       2022-05-07
# 4         7         87.5  Digital Wallet   Online       2022-10-02
#
#    Discount_Applied
# 0              True
# 1              True
# 2             False
# 3             False
# ...

# %%
df.to_csv("Retail_Cleaned.csv",index=False)
